# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekChaganti/DWDM1/blob/main/DWDM_Exp_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Read the dataset into a DataFrame

df = pd.read_csv("/content/kc_house_data.csv")

#Risplay the first few rows of the DataFrame
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...    7.0      1180.0            0.0
# 1      7242     2.0           0     0  ...    7.0      2170.0          400.0
# 2     10000     1.0           0     0  ...    6.0       770.0            0.0
# 3      5000     1.0           0     0  ...    7.0      1050.0          910.0
# 4      8080     1.0           0     0  ...    8.0      1680.0            0.0
# 5    101930     1.0           0     0  ...   11.0      3890.0         1530.0
# 6      6819     2.0           0     0  ...    7.0      1715.0            0.0
# 7      9711     1.0           0     0  ...    7.0      1060.0            0.0
# 8      7470     1.0           0     0  ...    7.0      1050.0          730.0
# 9      6560     2.0           0     0  ...    7.0      1890.0            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0    1955.0           0.0  98178.0  47.5112 -122.257         1340.0
# 1    1951.0        1991.0  98125.0  47.7210 -122.319         1690.0
# 2    1933.0           0.0  98028.0  47.7379 -122.233         2720.0
# 3    1965.0           0.0  98136.0  47.5208 -122.393         1360.0
# 4    1987.0           0.0  98074.0  47.6168 -122.045         1800.0
# 5    2001.0           0.0  98053.0  47.6561 -122.005         4760.0
# 6    1995.0           0.0  98003.0  47.3097 -122.327         2238.0
# 7    1963.0           0.0  98198.0  47.4095 -122.315         1650.0
# 8    1960.0           0.0  98146.0  47.5123 -122.337         1780.0
# 9    2003.0           0.0  98038.0  47.3684 -122.031         2390.0
#
#    sqft_lot15
# 0      5650.0
# 1      7639.0
# 2      8062.0
# 3      5000.0
# 4      7503.0
# 5    101930.0
# 6      6819.0
# 7      9711.0
# 8      8113.0
# 9      7570.0
#
# [10 rows x 21 columns]

# %%
# Create a figure with two subplots for histograms

fig = plt.figure(figsize=(12, 6))

sqft = fig.add_subplot(121) #Subplot for square footage histogram

cost = fig.add_subplot(122) # Subplot for housing prices histogram

# Plot the histogram for square footage

sqft.hist(df.sqft_living, bins=80)

sqft.set_xlabel('Ft^2')

sqft.set_title("Histogram of House Square Footage")

#Plot the histogram for housing prices

cost.hist(df.price, bins=80)

cost.set_title("Histogram of Housing Prices")

cost.set_xlabel('Price ($)')

# Show the histograms.

plt.show()

# %%
# Fit a linear regression model using statsmodels
m = ols('price ~ sqft_living', df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.492
# Method:                 Least Squares   F-statistic:                 1.844e+04
# Date:                Mon, 04 Mar 2024   Prob (F-statistic):               0.00
# Time:                        06:00:37   Log-Likelihood:            -2.6426e+05
# No. Observations:               19023   AIC:                         5.285e+05
# Df Residuals:                   19021   BIC:                         5.285e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -4.939e+04   4696.088    -10.517      0.000   -5.86e+04   -4.02e+04
# sqft_living   284.5700      2.095    135.809      0.000     280.463     288.677
# ==============================================================================
# Omnibus:                    13201.948   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           519717.914
# Skew:                           2.848   Prob(JB):                         0.00
# Kurtosis:                      27.965   Cond. No.                     5.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#plot a jointplot with a regression line using seabron
sns.jointplot(x="sqft_living",y="price",data=df,kind='reg',height=5)
plt.show()
